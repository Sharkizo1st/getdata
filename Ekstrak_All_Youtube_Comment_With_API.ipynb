# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharkizo1st/getdata/blob/main/Ekstrak_All_Youtube_Comment_With_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# YOUTUBE API required to get started

# %%
dev = "INSERT API KEY HERE"

# %% [markdown]
# FOR DATA MINING

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2

# %% [markdown]
# enter YouTube videoID to get data
#  You can collect comments from more than 1 video by for i in ['videoID1', 'videoID2', 'videoID3']:

# %%
df = pd.DataFrame()
for i in ['u5pI1fxseII']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %% [markdown]
# let's check the results;  seen it's amazing!

# %%
df
# Out:
#                      author            updated_at  like_count  \
# 0         @rannygartina8442  2024-03-15T11:25:59Z           1
# 1          @user-vj5vo8ku6p  2024-03-15T08:15:25Z           0
# 2                @breakhart  2024-03-15T05:13:59Z           1
# 3             @mrsofian2495  2024-03-13T23:52:50Z           1
# 4           @alexboboto3855  2024-03-12T07:29:31Z           1
# ...                     ...                   ...         ...
# 6721  @wahyututichannel9787  2023-12-29T04:25:19Z          25
# 6722           @suharto7642  2023-12-29T04:24:08Z           0
# 6723             @shortvice  2023-12-29T04:22:54Z           1
# 6724             @imams6106  2023-12-29T04:22:38Z           0
# 6725        @danielowen9366  2023-12-29T04:21:22Z           0
#
#                                                    text     video_id  public
# 0                     Kasihan yang gk punya smartphone,  u5pI1fxseII    True
# ...

# %% [markdown]
# sort by number of likes

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                           author            updated_at  like_count  \
# 3047  @salmanalrasyidofficial444  2024-01-01T11:13:52Z        1681
# 4681             @kotablitar7735  2023-12-29T20:33:15Z         679
# 6062             @Belumadanama88  2023-12-29T08:03:58Z         640
# 5941             @nsetiaalam4660  2023-12-29T08:45:56Z         362
# 6493                    @reza961  2023-12-29T05:54:44Z         356
# 6511             @pramnasima5877  2023-12-29T05:51:13Z         224
# 3783                @beotherjhon  2024-01-01T01:59:36Z         206
# 4013       @arumgondangmanis4580  2023-12-31T16:21:33Z         201
# 3678             @robbysolih2022  2024-01-01T04:05:13Z         184
# 4623              @davitpery2060  2023-12-29T23:47:55Z         175
#
#                                                    text     video_id  public
# 3047  Yang setuju ubah hukum koruptor menjadi hukum ...  u5pI1fxseII    True
# ...

# %% [markdown]
# Check total comments per video ID

# %%
df['video_id'].value_counts()
# Out:
# u5pI1fxseII    6726
# Name: video_id, dtype: int64

# %% [markdown]
# let's set save to .csv

# %%
df.to_csv('result.csv',index=False)

# %% [markdown]
# run this code for the results and they can be downloaded

# %%
# !cat result.csv
